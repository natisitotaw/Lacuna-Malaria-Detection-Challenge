# %%
# !pip install gdown
import gdown

# File ID from the Google Drive link
file_id = '16T40TdpaB8VXohm50SySREwrzbuPcJBC'
destination = 'data.zip'  # Change this to your preferred name

# Download the file
gdown.download(f'https://drive.google.com/uc?id={file_id}', destination, quiet=False)
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=16T40TdpaB8VXohm50SySREwrzbuPcJBC
# From (redirected): https://drive.google.com/uc?id=16T40TdpaB8VXohm50SySREwrzbuPcJBC&confirm=t&uuid=f3358285-192b-4da7-ad90-1048a8e6952e
# To: /kaggle/working/data.zip
# 100%|██████████| 4.29G/4.29G [01:09<00:00, 61.5MB/s]
# 'data.zip'

# %%
import zipfile

# Unzip the file
with zipfile.ZipFile(destination, 'r') as zip_ref:
    zip_ref.extractall('data')  # Change to your preferred extraction path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import zipfile
#       3 # Unzip the file
# ----> 4 with zipfile.ZipFile(destination, 'r') as zip_ref:
#       5     zip_ref.extractall('data')  # Change to your preferred extraction path
#
# NameError: name 'destination' is not defined

# %%
import os

# Delete the zip file
if os.path.exists(destination):
    os.remove(destination)
    print(f"{destination} has been deleted.")
else:
    print(f"{destination} not found.")

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Specify the extracted folder path
folder_path = 'data'  # Update with your actual path

# Get a list of all image files in the folder
image_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith(('png', 'jpg', 'jpeg'))]

# Select 4 random images
random_images = random.sample(image_files, 4)

# Display the selected images
plt.figure(figsize=(10, 10))

for i, image in enumerate(random_images):
    img = mpimg.imread(image)
    plt.subplot(2, 2, i+1)
    plt.imshow(img)
    plt.axis('off')

plt.show()

# %%
import os

def print_folder_tree(path, level=0):
    if not os.path.isdir(path):
        print(f"{path} is not a valid directory.")
        return

    prefix = "    " * level
    print(f"{prefix}|-- {os.path.basename(path)}/")

    try:
        for item in os.listdir(path):
            item_path = os.path.join(path, item)
            if os.path.isdir(item_path):  # Only consider directories
                print_folder_tree(item_path, level + 1)
    except PermissionError:
        print(f"{prefix}    |-- [Permission Denied]")

# Example usage
path = "/kaggle/working/path_to_extract"  # Replace with your desired path
print_folder_tree(path)

# %%
import os

# Define the extracted folder path and the filename you're looking for
extracted_folder_path = '/kaggle/working/path_to_extract'  # Change this to the path where you extracted the zip file
file_name = 'id_k6s11k3klo.jpg'

# Search for the file in the folder and its subfolders
file_found = False
for root, dirs, files in os.walk(extracted_folder_path):
    if file_name in files:
        file_found = True
        break

# Print True if the file exists, otherwise False
print(file_found)
